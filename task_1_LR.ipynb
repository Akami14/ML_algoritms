# %% [markdown]
# # Урок 1. Алгоритм линейной регрессии. Градиентный спуск.

# %% [markdown]
# ## <center>Практическая часть<a class="anchor" id="practice"></a><center>

# %% [markdown]
# Смоделируем работу градиентного спуска при помощи Numpy.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
# Визуализируем изменение весов (красной точкой обозначены истинные веса, сгенерированные вначале)
plt.figure(figsize=(13, 6))
plt.title('Gradient descent')
plt.xlabel(r'$w_1$')
plt.ylabel(r'$w_2$')

plt.scatter(w_list[:, 0], w_list[:, 1])
plt.scatter(w_true[0], w_true[1], c='r')
plt.plot(w_list[:, 0], w_list[:, 1])

plt.show()

# %% [markdown]
# После каждой итерации значения искомых весов приближаются к истинным, однако, не становятся им равны из-за шума, добавленного в вектор ответов.

# %%
# Визуализируем изменение функционала ошибки
plt.plot(range(len(errors)), errors)
plt.title('MSE')
plt.xlabel('Iteration number')
plt.ylabel('MSE')
# Out:
# Text(0, 0.5, 'MSE')

# %% [markdown]
# Видно, что изменение монотонно и начинается с высокой точки, после определенного количества итераций выходя на асимптоту.

# %% [markdown]
# ## Пример задачи<a class="anchor" id="example"></a><center>

# %% [markdown]
# __Задача:__ предсказание баллов ЕГЭ ученика в зависимости от кол-ва лет стажа его репетитора

# %%
X = np.array([[ 1,  1],
              [ 1,  1],
              [ 1,  2],
              [ 1,  5],
              [ 1,  3],
              [ 1,  0],
              [ 1,  5],
              [ 1, 10],
              [ 1,  1],
              [ 1,  2]])

# %%
y = [45, 55, 50, 55, 60, 35, 75, 80, 50, 60]

# %%
plt.scatter(X[:, 1], y);

# %% [markdown]
# Уравнение прямой: $y = a*x + b$

# %% [markdown]
# ### Метод наименьших квадратов (МНК)

# %% [markdown]
# $$w = (X^{T}X)^{-1}X^{T}y.$$

# %% [markdown]
# ### Посмотрим веса

# %%
W_analytical = np.linalg.inv(np.dot(X.T, X)) @ X.T @ y
W_analytical
# Out:
# array([45.0625,  3.8125])

# %%
y_pred_analytical = W_analytical[0] * X[:, 0] + W_analytical[1] * X[:, 1]
y_pred_analytical = X @ W_analytical

# %%
def calc_mae(y, y_pred):
    err = np.mean(np.abs(y - y_pred))
    return err

def calc_mse(y, y_pred):
    err = np.mean((y - y_pred)**2)
    return err

# %%
calc_mae(y, y_pred1), calc_mse(y, y_pred1)
# Out:
# (8.5, 97.5)

# %%
calc_mae(y, y_pred2), calc_mse(y, y_pred2)
# Out:
# (9.0, 188.75)

# %%
calc_mae(y, y_pred_analytical), calc_mse(y, y_pred_analytical)
# Out:
# (5.7875, 43.96875)

# %% [markdown]
# ### Градиентный спуск

# %% [markdown]
# $$\nabla_{w}Q(w,X) = \frac{2}{l}X^{T}(Xw-y).$$

# %% [markdown]
# 1. Инициализация w
#
# 2. Цикл по k = 1,2,3,...:
#
#     * $w^{k} = w^{k-1} - \eta_{k}\nabla Q(w^{k-1}, X)$
#
#     * Если $||w^{k} - w^{k-1}|| < \epsilon$, то завершить.

# %%
W = np.random.normal(size=(X.shape[1]))
W
# Out:
# array([-0.03510077, -0.82561501])

# %%
eta = 0.02 # величина шага

# %%
X.shape,  W.shape
# Out:
# ((10, 2), (2,))

# %%
n = len(y)
dQ = 2/n * X.T @ (X @ W - y) # градиент функции ошибки
dQ
# Out:
# array([-15.35175446,   2.78380397])

# %%
grad = eta * dQ
grad
# Out:
# array([-0.15351754,  0.02783804])

# %%
print(f'previous weights', W)
W = W - grad
print(f'new weights', W)
# Out:
# previous weights [28.22929764  6.86494171]
# new weights [28.38281518  6.83710367]

# %%
y_pred_grad = X @ W
plt.scatter(X[:, 1], y)
plt.plot(X[:, 1], y_pred_grad, label='gradient descent', c='g')
plt.legend()
plt.show()

# %% [markdown]
# ### Домашнее задание <a class="anchor" id="hw"></a><center>

# %% [markdown]
# 1. Подберите скорость обучения (eta) и количество итераций

# %%
n = X.shape[0]
eta = 1e-2 
n_iter = 100

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    for k in range(W.shape[0]):
        W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    if i % 10 == 0:
        eta /= 1.1
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')
# Out:
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [2.08 4.27], MSE = 3047.75
# Iteration #10: W_new = [ 6.67106886 10.61676385], MSE = 749.71
# Iteration #20: W_new = [ 9.49320908 10.25731657], MSE = 648.91
# Iteration #30: W_new = [11.85740092  9.83349244], MSE = 570.46
# Iteration #40: W_new = [13.86876921  9.46898661], MSE = 508.03
# Iteration #50: W_new = [15.59085668  9.15672679], MSE = 457.73
# Iteration #60: W_new = [17.07337653  8.88789585], MSE = 416.77
# Iteration #70: W_new = [18.35601294  8.65530964], MSE = 383.06
# Iteration #80: W_new = [19.47073522  8.45317196], MSE = 355.08
# Iteration #90: W_new = [20.44350656  8.27677488], MSE = 331.65

# %%
def search_alpha_iteration(eta, iteration): 
    n = X.shape[0]
    W = np.array([1, 0.5])
    print(f'Number of objects = {n} \
           \nLearning rate = {eta} \
           \nInitial weights = {W} \n')

    for i in range(iteration):
        y_pred = np.dot(X, W)
        err = calc_mse(y, y_pred)
        for k in range(W.shape[0]):
            W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
        if i % 10 == 0:
            eta /= 1.1
        yield(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')

# %% [markdown]
# ### Подберем alpha задав ее в определеном диапазоне

# %%
n = X.shape[1]
alphas = np.arange(0.0001, 0.1, 0.001)
W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rates = {alphas} \
       \nInitial weights = {W} \n')
for alpha in alphas:
    print('Значение скорости обучения alpha - ',alpha)
    for i in range(100):
        y_pred = np.dot(X, W)
        err = calc_mse(y, y_pred)
        for k in range(W.shape[0]):
            W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
        if i % 10 == 0:
            alpha /= 1.1
            print(f'Iteration #{i}: W_new = {W}, MSE = {round(err,2)}')
# Out:
# Number of objects = 2
# Learning rates = [0.0001 0.0011 0.0021 0.0031 0.0041 0.0051 0.0061 0.0071 0.0081 0.0091
#  0.0101 0.0111 0.0121 0.0131 0.0141 0.0151 0.0161 0.0171 0.0181 0.0191
#  0.0201 0.0211 0.0221 0.0231 0.0241 0.0251 0.0261 0.0271 0.0281 0.0291
#  0.0301 0.0311 0.0321 0.0331 0.0341 0.0351 0.0361 0.0371 0.0381 0.0391
#  0.0401 0.0411 0.0421 0.0431 0.0441 0.0451 0.0461 0.0471 0.0481 0.0491
#  0.0501 0.0511 0.0521 0.0531 0.0541 0.0551 0.0561 0.0571 0.0581 0.0591
#  0.0601 0.0611 0.0621 0.0631 0.0641 0.0651 0.0661 0.0671 0.0681 0.0691
#  0.0701 0.0711 0.0721 0.0731 0.0741 0.0751 0.0761 0.0771 0.0781 0.0791
#  0.0801 0.0811 0.0821 0.0831 0.0841 0.0851 0.0861 0.0871 0.0881 0.0891
#  0.0901 0.0911 0.0921 0.0931 0.0941 0.0951 0.0961 0.0971 0.0981 0.0991]
# Initial weights = [1.  0.5]
#
# Значение скорости обучения alpha -  0.0001
# Iteration #0: W_new = [ 6.4  19.35], MSE = 3047.75
# Iteration #10: W_new = [19.96966932  8.87179137], MSE = 379.6
# Iteration #20: W_new = [29.27719328  6.70531799], MSE = 172.93
# Iteration #30: W_new = [35.16120834  5.60976141], MSE = 94.66
# Iteration #40: W_new = [38.85365942  4.93848587], MSE = 63.9
# Iteration #50: W_new = [41.16920131  4.51849616], MSE = 51.81
# Iteration #60: W_new = [42.62118483  4.25519525], MSE = 47.05
# Iteration #70: W_new = [43.53165976  4.0900943 ], MSE = 45.18
# Iteration #80: W_new = [44.10257814  3.98656703], MSE = 44.45
# Iteration #90: W_new = [44.46057568  3.9216497 ], MSE = 44.16
# Значение скорости обучения alpha -  0.0011
# Iteration #0: W_new = [44.68506002  3.88094292], MSE = 44.04
# Iteration #10: W_new = [44.82582417  3.85541751], MSE = 44.0
# Iteration #20: W_new = [44.91409111  3.83941166], MSE = 43.98
# Iteration #30: W_new = [44.96943938  3.82937511], MSE = 43.97
# Iteration #40: W_new = [45.00414582  3.82308163], MSE = 43.97
# Iteration #50: W_new = [45.02590869  3.81913527], MSE = 43.97
# Iteration #60: W_new = [45.03955522  3.81666068], MSE = 43.97
# Iteration #70: W_new = [45.04811235  3.81510898], MSE = 43.97
# Iteration #80: W_new = [45.05347814  3.81413597], MSE = 43.97
# Iteration #90: W_new = [45.05684279  3.81352585], MSE = 43.97
# Значение скорости обучения alpha -  0.0021
# Iteration #0: W_new = [45.05895262  3.81314326], MSE = 43.97
# Iteration #10: W_new = [45.06027559  3.81290336], MSE = 43.97
# Iteration #20: W_new = [45.06110517  3.81275293], MSE = 43.97
# Iteration #30: W_new = [45.06162537  3.8126586 ], MSE = 43.97
# Iteration #40: W_new = [45.06195156  3.81259945], MSE = 43.97
# Iteration #50: W_new = [45.0621561   3.81256236], MSE = 43.97
# Iteration #60: W_new = [45.06228435  3.8125391 ], MSE = 43.97
# Iteration #70: W_new = [45.06236478  3.81252452], MSE = 43.97
# Iteration #80: W_new = [45.06241521  3.81251538], MSE = 43.97
# Iteration #90: W_new = [45.06244683  3.81250964], MSE = 43.97
# Значение скорости обучения alpha -  0.0031
# Iteration #0: W_new = [45.06246666  3.81250605], MSE = 43.97
# Iteration #10: W_new = [45.06247909  3.81250379], MSE = 43.97
# Iteration #20: W_new = [45.06248689  3.81250238], MSE = 43.97
# Iteration #30: W_new = [45.06249178  3.81250149], MSE = 43.97
# Iteration #40: W_new = [45.06249485  3.81250093], MSE = 43.97
# Iteration #50: W_new = [45.06249677  3.81250059], MSE = 43.97
# Iteration #60: W_new = [45.06249797  3.81250037], MSE = 43.97
# Iteration #70: W_new = [45.06249873  3.81250023], MSE = 43.97
# Iteration #80: W_new = [45.0624992   3.81250014], MSE = 43.97
# Iteration #90: W_new = [45.0624995   3.81250009], MSE = 43.97
# Значение скорости обучения alpha -  0.0041
# Iteration #0: W_new = [45.06249969  3.81250006], MSE = 43.97
# Iteration #10: W_new = [45.0624998   3.81250004], MSE = 43.97
# Iteration #20: W_new = [45.06249988  3.81250002], MSE = 43.97
# Iteration #30: W_new = [45.06249992  3.81250001], MSE = 43.97
# Iteration #40: W_new = [45.06249995  3.81250001], MSE = 43.97
# Iteration #50: W_new = [45.06249997  3.81250001], MSE = 43.97
# Iteration #60: W_new = [45.06249998  3.8125    ], MSE = 43.97
# Iteration #70: W_new = [45.06249999  3.8125    ], MSE = 43.97
# Iteration #80: W_new = [45.06249999  3.8125    ], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0051
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0061
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0071
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0081
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0091
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0101
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.011099999999999999
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0121
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0131
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0141
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.015099999999999999
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0161
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0171
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0181
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0191
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0201
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0211
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.022099999999999998
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0231
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0241
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0251
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0261
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0271
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0281
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0291
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0301
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0311
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.032100000000000004
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.033100000000000004
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.034100000000000005
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.035100000000000006
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.03610000000000001
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0371
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0381
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0391
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.040100000000000004
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.041100000000000005
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.042100000000000005
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.043100000000000006
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0441
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0451
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0461
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0471
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.048100000000000004
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.049100000000000005
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.050100000000000006
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.051100000000000007
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.05210000000000001
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0531
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0541
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0551
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.056100000000000004
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.057100000000000005
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.058100000000000006
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.05910000000000001
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0601
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0611
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0621
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0631
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0641
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0651
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0661
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0671
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.06810000000000001
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.06910000000000001
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.07010000000000001
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.07110000000000001
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.07210000000000001
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0731
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0741
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0751
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0761
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0771
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0781
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0791
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0801
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0811
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0821
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.08310000000000001
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.08410000000000001
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.08510000000000001
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.08610000000000001
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.08710000000000001
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0881
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0891
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0901
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0911
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0921
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0931
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0941
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0951
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0961
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0971
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.0981
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97
# Значение скорости обучения alpha -  0.09910000000000001
# Iteration #0: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #10: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #20: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #30: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #40: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #50: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #60: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #70: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #80: W_new = [45.0625  3.8125], MSE = 43.97
# Iteration #90: W_new = [45.0625  3.8125], MSE = 43.97

# %% [markdown]
# #### alpha -  0.0011 и итерация 20 вполне оптимальны можно взять и alpha  0.0021 и сразу при 0 итерацие в минимуме по MSE оказаться

# %% [markdown]
# 2*. В этом коде мы избавляемся от итераций по весам, но тут есть ошибка, исправьте ее

# %%
n = X.shape[1]
alpha = 1e-2
W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {alpha} \
       \nInitial weights = {W} \n')

for i in range(100):
    y_pred = np.dot(W, X)
    err = calc_mse(y, y_pred)
#     for k in range(W.shape[0]):
#         W[k] -= alpha * (1/n * 2 * np.sum(X[k] * (y_pred - y)))
    W -= alpha * (1/n * 2 * np.sum(X * (y_pred - y)))
    W_pred = W
    if i % 10 == 0:
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err,2)}')
# Out:
# Number of objects = 2
# Learning rate = 0.01
# Initial weights = [1.  0.5]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23004\2829653485.py in <module>
#       7
#       8 for i in range(100):
# ----> 9     y_pred = np.dot(W, X)
#      10     err = calc_mse(y, y_pred)
#      11 #     for k in range(W.shape[0]):
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (2,) and (10,2) not aligned: 2 (dim 0) != 10 (dim 0)

# %% [markdown]
# ### Решение

# %%
n = X.shape[0]
eta = 1e-2 
n_iter = 100

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    dQ = 2/n * X.T @ (y_pred - y)
    W -= eta * dQ
    if i % 10 == 0:
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err,2)}')
# Out:
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [2.08 4.27], MSE = 3047.75
# Iteration #10: W_new = [ 7.0011236 10.6169007], MSE = 738.65
# Iteration #20: W_new = [10.3486292  10.10603105], MSE = 622.03
# Iteration #30: W_new = [13.38789582  9.55618391], MSE = 525.24
# Iteration #40: W_new = [16.16088505  9.05336203], MSE = 444.66
# Iteration #50: W_new = [18.69110735  8.59454545], MSE = 377.58
# Iteration #60: W_new = [20.99981865  8.17589626], MSE = 321.72
# Iteration #70: W_new = [23.10641138  7.79389815], MSE = 275.22
# Iteration #80: W_new = [25.02858024  7.44534246], MSE = 236.5
# Iteration #90: W_new = [26.78247081  7.12730145], MSE = 204.27

# %% [markdown]
# 3*. Вместо того, чтобы задавать количество итераций, задайте другое условие останова алгоритма - когда веса перестают изменяться меньше определенного порога $\epsilon$.

# %%
n = X.shape[1]
eta = 0.011
W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

y_pred = np.dot(X, W)
err = calc_mse(y, y_pred)
i =0
while err >= 44:
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    dQ = 2/n * X.T @ (y_pred - y)
    W -= eta * dQ
    i +=1
    if i % 10 == 0:
        eta /= 1.1
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err,2)}')
# Out:
# Number of objects = 2
# Learning rate = 0.011
# Initial weights = [1.  0.5]
#
# Iteration #10: W_new = [18.95229787  3.08632561], MSE = 960.06
# Iteration #20: W_new = [29.23388081  6.35672938], MSE = 175.76
# Iteration #30: W_new = [34.7346085   5.68349343], MSE = 98.64
# Iteration #40: W_new = [38.02905705  5.08790582], MSE = 69.13
# Iteration #50: W_new = [40.0991874   4.71252021], MSE = 56.41
# Iteration #60: W_new = [41.44541454  4.46840268], MSE = 50.53
# Iteration #70: W_new = [42.34844147  4.30465267], MSE = 47.64
# Iteration #80: W_new = [42.97142879  4.19168352], MSE = 46.14
# Iteration #90: W_new = [43.41229905  4.1117385 ], MSE = 45.31
# Iteration #100: W_new = [43.73157228  4.05384322], MSE = 44.84
# Iteration #110: W_new = [43.96767458  4.01102971], MSE = 44.56
# Iteration #120: W_new = [44.14561674  3.97876264], MSE = 44.38
# Iteration #130: W_new = [44.2820542   3.95402181], MSE = 44.27
# Iteration #140: W_new = [44.38831472  3.93475311], MSE = 44.19
# Iteration #150: W_new = [44.47225423  3.91953197], MSE = 44.14
# Iteration #160: W_new = [44.53942012  3.90735247], MSE = 44.1
# Iteration #170: W_new = [44.59379568  3.8974923 ], MSE = 44.07
# Iteration #180: W_new = [44.63828587  3.88942469], MSE = 44.06
# Iteration #190: W_new = [44.67504004  3.88275989], MSE = 44.04
# Iteration #200: W_new = [44.70567003  3.87720561], MSE = 44.03
# Iteration #210: W_new = [44.73139981  3.87253992], MSE = 44.02
# Iteration #220: W_new = [44.75316979  3.86859226], MSE = 44.01
# Iteration #230: W_new = [44.77171049  3.86523019], MSE = 44.01
# Iteration #240: W_new = [44.78759519  3.86234975], MSE = 44.0
# Iteration #250: W_new = [44.80127817  3.85986855], MSE = 44.0

# %%
def mse_critical(critical):
    n = X.shape[1]
    eta = 0.011
    W = np.array([1, 0.5])
    print(f'Number of objects = {n} \
           \nLearning rate = {eta} \
           \nInitial weights = {W} \n')
    
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    i =0
    while err >= critical:
        y_pred = np.dot(X, W)
        err = calc_mse(y, y_pred)
        dQ = 2/n * X.T @ (y_pred - y)
        W -= eta * dQ
        i +=1
        if i % 10 == 0:
            eta /= 1.1
            yield (f'Iteration #{i}: W_new = {W}, MSE = {round(err,2)}')

# %%
for el in mse_critical(60):
    print(el)
# Out:
# Number of objects = 2
# Learning rate = 0.011
# Initial weights = [1.  0.5]
#
# Iteration #10: W_new = [18.95229787  3.08632561], MSE = 960.06
# Iteration #20: W_new = [29.23388081  6.35672938], MSE = 175.76
# Iteration #30: W_new = [34.7346085   5.68349343], MSE = 98.64
# Iteration #40: W_new = [38.02905705  5.08790582], MSE = 69.13

# %% [markdown]
# ## Дополнительные материалы

# %% [markdown]
# 1. [Обучение с учителем. Обучение без учителя. Обучение с подкреплением. Видео](https://youtu.be/ku2oPMPht2I)
# 2. [Вывод аналитической формулы решения уравнения линейной регрессии](https://habr.com/ru/company/ods/blog/323890/#metod-naimenshih-kvadratov) (см. пункт 1.2)
# 3. [Математическое описание метода градиентного спуска](http://www.machinelearning.ru/wiki/index.php?title=%D0%9C%D0%B5%D1%82%D0%BE%D0%B4_%D0%B3%D1%80%D0%B0%D0%B4%D0%B8%D0%B5%D0%BD%D1%82%D0%BD%D0%BE%D0%B3%D0%BE_%D1%81%D0%BF%D1%83%D1%81%D0%BA%D0%B0)
# 4. [Документация NumPy](https://docs.scipy.org/doc/numpy-1.16.0/reference/routines.html)
# 5. [Метрики для задачи регрессии. Видео](https://youtu.be/vh2smjQyhp8)

# %% [markdown]
# ## Summary

# %% [markdown]
# * Линейная регрессия - простой, но зачастую эффективный, способ приближать вещественную целевую переменную через линейную комбинацию признаков
# * Решение регрессии - МНК, можно решать аналитически, но на практике - градиентный спуск (GD, Gradient Descent)
# * MSE удобна для градиентного спуска, так как дифференцируема
# * Максимальное качество градиентного спуска достигается малыми шагами и большим кол-вом итераций

# %% [markdown]
# ### Определения
# *Машинное обучение*
#
# **Машинное обучение** — дисциплина, заключающаяся в извлечении знаний из известных данных.
#
# **Признак** — это индивидуальное измеримое свойство или характеристика наблюдения.
#
# **Обучающая выборка** — набор структурированных данных, используемый для обучения моделей.
#
# **Обучение с учителем** — это направление машинного обучения, объединяющее алгоритмы и методы построения моделей на основе множества примеров, содержащих пары "известный вход - известный выход".
#
# **Обучение без учителя** — направление машинного обучения, в которой для коррекции параметров обучаемой модели не используется целевая функция. Иными словами, в обучающих примерах при обучении без учителя не нужно иметь заранее заданные выходы модели.
#
# **Обучение с подкреплением** — раздел машинного обучения, изучающий поведение интеллектуальных агентов, действующих в некоторой среде и принимающих решения.
# ___________
#
# _Линейные модели_
#
# **Линейные модели** — такие модели, которые сводятся к суммированию значений признаков с некоторыми весами
#
# **Линейная регрессия** — модель зависимости переменной x от одной или нескольких других переменных (факторов, регрессоров, независимых переменных) с линейной функцией зависимости.
#
# **Метод наименьших квадратов** — способ вычисления весов линейной модели путем минимизации среднеквадратичного отклонения.
# ___________
#
# _Градиентный спуск_
#
# **Градиент функции** — $n$-мерный вектор из частных производных. Задает направление наискорейшего роста функции. $$ \nabla f(x_{1},...,x_{d}) = \left(\frac{\partial f}{\partial x_{i}}\right)^{d}_{i=1}.$$
#
# **Градиентный спуск** — метод нахождения локального экстремума функции (минимума или максимума) с помощью движения вдоль градиента.
